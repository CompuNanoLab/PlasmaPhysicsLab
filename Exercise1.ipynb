# %% [markdown]
# # Exercise 1
#
# Let's look at some trajectories. Run the following cells by clicking on the **Run** botton on the top.

# %%
# %run case1.py

# %% [markdown]
# A magnetic field has been applied to a charged particle with initial velocity different from zero.
#
# Can you recognize this kind of motion?
#
# What is the sign of the charge?

# %%
# %run case2.py

# %% [markdown]
# In your opinion what is changing in this case with respect to the previous one? We are still applying just a magnetic field.
